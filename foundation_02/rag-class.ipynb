# %%
import rag
index = rag.initialize_index()
# Out:
# Indexed 385 chunks from 95 documents

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
doc_rag = rag.RAG(index=index, llm_client=openai_client)

# %%
response = doc_rag.rag('llm as a judge')

# %%
print(response.answer)
# Out:
# ## Using LLM as a Judge
#
# In this context, an LLM (Large Language Model) serves as an evaluator for text responses based on specified criteria. Here are the key aspects of utilizing an LLM as a judge:
#
# ### 1. Evaluation Methods
# - **Reference-based Evaluation**: It compares new responses against a known reference (ground truth) to determine correctness. This method is useful for regression testing or scenarios where you have approved responses to benchmark against.
# - **Open-ended Evaluation**: This evaluates responses based on custom criteria when there isn't a reference available. It allows for flexibility in assessing new outputs based on defined metrics like verbosity or correctness.
#
# ### 2. Tutorial Steps
# - **Creating an Evaluation Dataset**: This involves building a toy Q&A dataset that includes questions, target responses, new imitated responses, and manual correctness labels to help define evaluation criteria.
# - **Designing an LLM Evaluator Prompt**: The prompt guides what the LLM is judging—whether it’s response correctness or another factor like verbosity.
# - **Running the LLM Judge**: Compare outcomes from the LLM with manual evaluations to ascertain its accuracy.
#
# ### 3. Installation and Setup
# - You'll need basic Python skills and an OpenAI API key to use the LLM evaluator.
# - It is recommended to run the exercises in Jupyter Notebook or Google Colab for better interaction and results visualization.
#
# ### 4. Evaluating Judge Quality
# You can analyze the performance of the LLM evaluator itself, treating it as a binary classification problem, to see how well it predicts correctness against manually labeled data.
#
# ### Note
# For further integration, results can also be uploaded to the Evidently Cloud platform, making it easier to track evaluations systematically.
#
# This information outlines how the LLM acts as a judge within a structured evaluation framework for text responses, ensuring outputs can be measured against set criteria effectively.

# %%
print(f"Found answer: {response.found_answer}")
print(f"Confidence: {response.confidence}")
print(f"Answer type: {response.answer_type}")
print(f"Follow-up questions: {response.followup_questions}")
# Out:
# Found answer: True
# Confidence: 0.95
# Answer type: explanation
# Follow-up questions: ['What are the custom criteria for evaluating responses?', 'Can you provide examples of reference-based evaluations?', 'How can I set up the LLM evaluator in my project?']
