# %%
import os
from dotenv import load_dotenv
from groq import Groq

load_dotenv()   

groq_client = Groq(api_key=os.getenv("GROQ_API_KEY"))

print("Groq client initialized successfully ")
# Out:
# Groq client initialized successfully

# %%
response = groq_client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "user", "content": "tell me a joke about Nirajan"}
    ]
)

print(response.choices[0].message.content)
# Out:
# I'm not aware of many jokes about Nirajan. However, I can try to make one up.
#
# Why did Nirajan the Nepali golfer bring a ladder to the golf course?
#
# Because he wanted to take his game to a higher level.
