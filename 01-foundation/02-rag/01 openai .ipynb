# %%
from openai import OpenAI

openai_client = OpenAI()

# %%
response = openai_client.responses.create(
    model="gpt-4o-mini",
    input="tell me a joke about Alexey"
)

# %%
print(response.output_text)
# Out:
# Why did Alexey bring a ladder to the bar?
#
# Because he heard the drinks were on the house!

# %%
messages = [
    {"role": "user", "content": "tell me a joke about Alexey"}
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

# %%
print(response.usage)
# Out:
# ResponseUsage(input_tokens=14, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=22, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=36)

# %%
messages = [
    {"role": "user", "content": "tell me a bad time story about a unicorn"}
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

# %%
MODEL_PRICES = {
    "gpt-4o-mini": {"input": 0.15, "output": 0.60},
    "gpt-5-nano": {"input": 0.075, "output": 0.30},
    "gpt-5-mini": {"input": 0.25, "output": 2.00},
    "gpt-5.2": {"input": 1.75, "output": 14.00},
    "gpt-5.2-pro": {"input": 21.00, "output": 168.00},
}

# %%
def calculate_cost(model_name: str, input_tokens: int, output_tokens: int) -> float:
    prices = MODEL_PRICES[model_name.lower()]
    input_cost = (input_tokens / 1_000_000) * prices["input"]
    output_cost = (output_tokens / 1_000_000) * prices["output"]
    return input_cost + output_cost

# %%
usage = response.usage

cost = calculate_cost(
    model_name="gpt-4o-mini",
    input_tokens=usage.input_tokens,
    output_tokens=usage.output_tokens
)

print(f"Cost: ${cost:.6f}")
# Out:
# Cost: $0.000322

# %%
stream = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages,
    stream=True
)

response = None
for event in stream:
    if hasattr(event, 'delta'):
        print(event.delta, end='')
    if hasattr(event, 'response'):
        response = event.response
# Out:
# Once in a magical forest, there lived a unicorn named Sparkle. Unlike most unicorns, who were known for their beauty and grace, Sparkle had a knack for getting into trouble.
#
# One sunny morning, Sparkle decided to venture beyond the magical forest to explore a nearby village. When she arrived, she was amazed by the humans and their strange ways. Instead of using her time wisely, she pranced around, showing off her shimmering horn, which caught the attention of the villagers.
#
# But rather than being admired, Sparkle accidentally knocked over a vendor's cart full of vegetables with her excited jumps. Carrots flew everywhere, landing on people’s heads, and a particularly grumpy old man slipped on a tomato, falling right into a puddle.
#
# Horrified, Sparkle tried to help but only made things worse. With every attempt to clean up, she ended up causing more chaos—spilling water, knocking over more carts, and startling the animals. The villagers started to chase her away, shouting about the “mischief-making unicorn.”
#
# Feeling disheartened, Sparkle fled back to the safety of the forest. As she lay under her favorite tree, she realized that her adventurous spirit might make her feel alive, but it could also create mess and confusion.
#
# Determined to make amends, Sparkle decided to return to the village the next day, but this time, she brought a cart full of flowers and a sincere apology. This time, the villagers welcomed her with open arms, not for her horn, but for her willingness to learn from her mistakes.
#
# From that day forward, Sparkle became a friend to the village, helping to plant gardens and deliver flowers to brighten people’s day. Though her adventures began on a bad note, she learned that kindness could turn a messy situation into something beautiful.
#
# And so, Sparkle found her true magic—not just in her horn, but in her heart.

# %%
response.usage
# Out:
# ResponseUsage(input_tokens=16, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=392, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=408)

# %%
instructions = "make sure to add emojis"
user_prompt = "tell me a bad time story about a unicorn"

messages = [
    {"role": "system", "content": instructions},
    {"role": "user", "content": user_prompt},
]

response = openai_client.responses.create(
    model='gpt-4o-mini',
    input=messages
)

# %%
print(response.output_text)
# Out:
# Once upon a time in a sparkling kingdom, there lived a unicorn named Sparkle 🦄. Sparkle had a sparkling rainbow mane and a magical horn that could heal anything. But despite her beauty, Sparkle was a bit of a troublemaker.
#
# One day, she ventured too far from her cozy meadow, tempted by the tales of a forbidden forest 🌲. The villagers warned her, saying it was filled with mischievous creatures and dark magic 🕷️. But Sparkle, feeling particularly brave, galloped into the trees, ignoring the whispers of caution.
#
# Deep in the forest, she stumbled upon a mischievous goblin named Grumble. Grumble was known for his tricks and pranks, and he quickly decided that Sparkle would be his next target. He enchanted her horn, turning it into a banana! 🍌
#
# At first, Sparkle was bewildered. She attempted to heal the flowers around her, but all that came out was fruity juice! The forest filled with laughter as creatures found it hilarious. Sparkle felt humiliated and longed for her magical horn back.
#
# Realizing she needed help, she approached the wise old owl 🦉 who resided in the tallest tree. The owl chuckled softly, but he sympathized with her plight. He told her the only way to reverse Grumble's spell was to outsmart him.
#
# Gathering her courage, Sparkle devised a plan. She painted herself in vibrant colors and pretended to be an enchanted fruit tree 🌈. When Grumble came to check out the "tree," Sparkle erupted, catching him off guard!
#
# With a swish of her newly vibrant mane, she countered the spell, turning his magic back on him. Suddenly, Grumble’s pranks boomeranged, and he found himself trapped in an endless loop of slip-ups 🍂.
#
# Feeling victorious, Sparkle returned home, but she learned a valuable lesson: sometimes, venturing too far and ignoring warnings can lead to sticky situations. She laughed and promised herself she'd think twice before chasing adventures in the future.
#
# And from that day on, Sparkle, while still indulging her curious spirit, made sure to stick closer to home, because bad times could always turn into good stories! 🌟
#
# The end! 🎉
